# %% [markdown]
# nesmeble de fonction qui separe les points par des hyperplans 1(wixi > 0). Algo de perceptrons qui permet de te determiner ton w, wt+1 = wt + xiyi, rappel si prodscalire de (wt,xi)Yi positif bien classe sinon mal calsse on modfie wt par wt+1 et donc quand on recalcul on ne sera pas forcement positif mais plus proche de 0  . Pour prouver la vc dim, tester les cas limites ex lorque dim des w est d voir quand n est plus grand que d.

# %% [markdown]
# Pour que les perceptrosn soit ok il faut que l espace soit lineaire separable . exemple des points ronds ou les -1 sont a l interieur et les 1 a l exterieur alors je ne puex pas separer de maniere lineaire mon espace. Or si je prend un kernel qui envoie les points du centre sur une autre dim et les autres sur les memes alors je pouraiis separer non pas dans R2 mais dans R3
